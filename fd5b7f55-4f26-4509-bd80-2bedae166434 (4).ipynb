# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# <b>Привет!</b>
#
# Меня зовут Сороколетов Илья и я буду проверять твой проект.
#
# Предлагаю общаться на «**ты**», но если тебе будет комфортнее общаться на «**вы**», то сообщи об этом в комментариях)
#
#
# Для твоего удобства, я буду выделять свои комментарии следующим образом:
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b> Самые важные замечания. Они указывают на ключевые моменты, которые влияют на конечный результат проекта. </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b> Советы или замечания, которые помогут сделать твою работу лучше, но необязательны к выполнению.
#
# </div>
#
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b> Так я выделяю все остальные комментарии.</div>
#
#
# Пометками <b>v1-v2-v3-...</b> я буду отмечать версию проверки. Так ты сможешь быстро найти мои новые комментарии.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения, например вот так:
#
# <div class="alert alert-info">
# <b>Комментарий студента: принято</b>
# <br>
# </div>
#
# <b>Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии.</b> Если ты оставляешь свои комментарии, то делай это под моими, чтобы сообщения были расположены в хронологическом порядке. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Перед отправкой работы я рекомендую нажимать Kernel -> Restart & Run All. Это перезапустит ядро и по очереди выполнит все ячейки. Так ты сможешь проверить, что всё работает корректно. Кнопка Kernel находится в панели сверху
#
# Обязательно задавай вопросы если они возникнут, а я перехожу к проверке)
#
# P.S. На всякий случай, я оставлю пустой шаблон для твоих комментариев ниже. Кликни два раза на мой комментарий, скопируй последние четыре строчки кода и вставляй их в пустую ячейку там, где ты хочешь оставить комментарий. Не забудь только перед этим сменить тип ячейки на Markdown. Быстро это можно сделать так: кликнуть на ячейку - нажать ESC - нажать M.
#
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Привет! Про ячейки Markdown упустил. Я думал, это строки с символом # 🙂
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
# <br>У нас огромный проект, в котором много заданий, а ты весь код уместил в 4 ячейках и все промежуточные выводы написал в виде комментариев к коду.
# <br>Разбей, пожалуйста, код на несколько ячеек и добавь свои рассуждения и промежуточные выводы после каждого раздела в ячейках типа markdown. Так будет более наглядно и проще комментировать твой код
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Разделил код на ячейки. Под каждой ячейкой с кодом написал вывод в ячейке Markdown.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
# <br>Посмотри, пожалуйста, на то, как сделаны первый и второй проект. Тогда ты поймёшь что я от тебя хочу) Каждый график нужно построить в отдельной ячейке и после этого вывести его на экран, а под ним написать выводы. Заполнение пропусков для каждого столбца тоже нужно провести в отдельной ячейке.
# <br>В твоём проекте нет ни одного вывода на экран. Я не смогу понять, верно ли ты построил графики. Не нужно комментировать код, по которому ты делаешь выводы)
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправил. Также внес уточнения в п.4 шага 2 про редкие и выбивающиеся значения в столбце "высота потолков": ранее указывал верхний лимит как 7 метров, сейчас указал как 5.3 метра.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Спасибо! Перехожу к проверке
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Откройте-файл-с-данными-и-изучите-общую-информацию." data-toc-modified-id="Откройте-файл-с-данными-и-изучите-общую-информацию.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Откройте файл с данными и изучите общую информацию.</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Посчитайте-и-добавьте-в-таблицу-новые-столбцы" data-toc-modified-id="Посчитайте-и-добавьте-в-таблицу-новые-столбцы-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Посчитайте и добавьте в таблицу новые столбцы</a></span></li><li><span><a href="#Проведите-исследовательский-анализ-данных" data-toc-modified-id="Проведите-исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Проведите исследовательский анализ данных</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
# 1. Загрузите данные из файла в датафрейм.
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')
#display(data.head(20))
data['floors_total'].isna().value_counts()
# Out:
# False    23613
# True        86
# Name: floors_total, dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Все библиотеки лучше импортировать отдельно в первой ячейке. Это позволит тебе в любой момент добавить ещё одну библиотеку без перезаписи переменных.
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента: поправил, перенес вверх matplotlib</b>
# <br>
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Для вывода таблиц лучше использовать функцию display
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента: Поменял</b>
# <br>
# </div>

# %%
# 2. Изучите общую информацию о полученном датафрейме.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
# 3. Постройте общую гистограмму для всех столбцов таблицы.
data.hist(figsize=(15, 20));

# %% [markdown]
# Вывод: в рассматриваемом датафрейме 22 столбца и 23699 строчек. В ряде столбцов имеются пропуски, некоторые из которых следует устранить на этапе предобработки. Также типы данных столбцов с количественными показателями целесообразно изменить с float на int, а тип данных столбца с датами - на тип данных datetime.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Графики построено верно!
# </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Если после кода вызывающего график добавить ";", то мы избавимся от строчки над графиком)
# </div>
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента: Добавил</b>
# <br>
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Здесь необходимо написать короткий вывод о проблемах с данными (пропуски, дубликаты, неверный тип данных, странные значения и т.д.)
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента: Добавил выше</b>
# <br>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Всё верно! Рекомендую создать универсальную функцию, которая будет на вход принимать датафрейм, а на выходе будет выводить все необходимые характеристики поочередно применяя методы head, describe, info, duplicated и т.п.
# </div>

# %% [markdown]
# ### Предобработка данных

# %%
# 1. Найдите и изучите пропущенные значения в столбцах.

# Проверим количество пропусков в каждом столбце датафрейма:
print(data.isna().sum())
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
# Заменим пропуски в столбце "высота потолков" на медианное значение:
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())
print(data.isna().sum())
display(data.head(10))
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Согласен с таким решением, так как основная часть данных в этом столбце находится в небольшом диапазоне.
# </div>

# %%
# Заменим пропуски в столбце "кол-во этажей" на медианное значение:
data['floors_total'] = data['floors_total'].fillna(data['floors_total'].median())
print(data.isna().sum())
display(data.head(10))
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# ...

# %%
# Проверим, не стал ли в результате произведенной замены этаж квартиры больше (выше), 
# чем этажность дома:
print(len(data.loc[data['floor'] > data['floors_total']]))
# Out:
# 37

# %% [markdown]
# Вывод: у 37 квартир этаж квартиры превышает максимальную этажность дома.

# %%
# По квартирам, у которых этаж превышает максимальную этажность дома, заменим этаж на последний 
# этаж максимальной этажности:
data.loc[data['floor'] > data['floors_total'], 'floor'] = data['floors_total']
print(data.loc[data['floor'] > data['floors_total']])
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Если мы заполняем таким способом, то нужно делать проверку, а не превышает ли этаж, на котором квартира общую этажность? Можно заменить на этаж квартиры либо оставить как есть
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента: Заменил выше</b>
# <br>
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Если тут пропуск, то значит квартира не продана. Эти пропуски заполнять не нужно
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента: Убрал замену пропусков в столбце "срок публикации объявления"</b>
# <br>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %%
# Заменим пропуски в столбце "жилая площадь" с помощью коэффициента, равного отношению средней
# площади квартир, по которым нет пропусков в жилой площади, к среднему значению жилой площади квартир, 
# по которым также нет пропусков.
# Найдем коэффицент:
k_gilaya = data.loc[data['living_area'] != 'NaN', 'total_area'].mean()/(data['living_area'].mean())
# print(k_gilaya)
# Поделим общую площадь квартир, у которых пропуски в жилой площади, на коэффициент:
data['living_area'] = data['living_area'].fillna(data['total_area']/k_gilaya)
print(data.isna().sum())
display(data.head(10))
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# ...

# %%
# Заменим пропуски в столбце "площадь кухни" аналогично замене жилой площади:
k_kuhnya = data.loc[data['kitchen_area'] != 'NaN', 'total_area'].mean()/(data['kitchen_area'].mean())
# print(k_kuhnya)
data['kitchen_area'] = data['kitchen_area'].fillna(data['total_area']/k_kuhnya)
print(data.isna().sum())
display(data.head(10))
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Прекрасный способ для замены! 👏🏻👏🏻👏🏻
# </div>

# %%
# Заменим пропуски в столбце "кол-во балконов" на ноль: 
data['balcony'] = data['balcony'].fillna(0)
print(data.isna().sum())
display(data.head(10))
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👌
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Пропуски в столбцах с картографическими данными лучше не трогать, так как мы не можем восстановить их с достаточной точностью. Лучше оставить их как есть.
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента: Убрал замену пропусков в столбцах "число парков в радиусе 3 км" и "число прудов в радиусе 3 км", также поправил вывод</b>
# <br>
# </div>

# %%
# Заменим пропуски в столбце "апартамент" на False:
data['is_apartment'] = data['is_apartment'].fillna(False)
print(data.isna().sum())
display(data.head(10))
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👌
# </div>

# %% [markdown]
# Вывод:
# 1. По результатам работы с пропусками в столбцах "кол-во балконов", "кол-во этажей", "жилая площадь" и "площадь кухни" пропущенные значения заполнены средними величинами. При этом по квартирам, у которых "приобретенный" этаж стал выше этажности самого дома, этаж заменен на последний этаж максимальной этажности дома. В столбце "апартамент" пропуски заменены на значение False (т.е. не являются апартаментами).
# Пропуски в столбце "название населенного пункта" заменять не будем, т.к. непонятно, на что их менять.
# Пропуски в географических столбцах  в части расстояния до центра, аэропорта, пруда и парка, количества прудов и парков в радиусе 3 км также оставим, т.к. их замена может привести к искажению данных. Пропуски в столбце "кол-во дней размещения объявления" также убирать не будем, т.к. квартиры на момент формирования датафрейма видимо были размещены в продаже.
#
# 2. Возникновение пропусков можно объяснить следующим:
# - в столбце "высота потолков" - например, в связи отсутствием данных у заполняющего;
# - в столбце "всего этажей" - например, из-за непонимания, сколько этажей указывать,
# если в доме есть цокольный или мансардный этаж;
# - в столбце "срок размещения объявления" - например, в связи несвоевременным снятием объявления
# по проданной квартире;
# - в столбцах с "жилой площадью" и "площадью кухни" - например, в квартирах студиях, где эти   площади совмещены;
# - в столбце "балконы" - например, заполняющий не посчитал нужным ставить ноль, если в квартире
# балконов нет
# - в столбце "апартамент" - например, заполняющий не владел информацией, является ли квартира
# апартаментом с точки зрения законодательства;
# - в столбцах с картографическими данными - возможно, они заполняются автоматически по координатам квартиры, которые определяются по введеному адресу. Например, системой не был распознан адрес квартиры при заполнении объявления.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Отличная работа! Не забывай, что не всегда стоит делать замену, ради замены. Очень важно обоснование. Иногда пропуски можно удалить (если их мало), либо вообще не трогать, если у нас нет возможности подобрать аргументированный способ замены
# </div>

# %%
#2. Рассмотрите типы данных в каждом столбце.
# Выясним типы данных во всех столбцах датафрейма:
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  float64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  float64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
# Изменим тип данных столбцов, в которых указаны количественные значения, с float64 на int.
data = data.astype({"floors_total":"int64", "balcony":"int64"})
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  int64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  float64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %%
# Изменим тип данных столбца "дата публикации объявления" на формат даты:
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  int64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  float64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  int64
# ...

# %% [markdown]
# Вывод:
# По результатам работы с типами данных в столбцах с количественными показателями тип данных изменен с float на int. Данное изменение лучше отражает суть данных в этих столбцах. В столбце "дата публикации объявления" тип данных изменен на datetime, что в дальнейшем позволит работать с датами из этого столбца.

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Методы fillna и astype можно применить к нескольким столбюца одновременно
#
# 	df.astype({ "col1": "float64", "col2": "int64"})
# <br>Если столбцов более двух, то можно применить цикл for для автоматизации процесса
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента: Поменял код на однострочный. Также убрал замену типа данных в столбцах "количество парков", "прудов в радиусе 3 км" и "срок размещения объявлений", т.к. в этих столбцах решили не заменять пропуски, соответственно, там остались NaN, которые не дают поменять тип данных </b>
# <br>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Тут вариантов несколько:
# <br>1. Произвести изменение типа не заполняя пропуски
#
#     import numpy as np
#     df['col'] = np.floor(pd.to_numeric(df['col'], errors='coerce')).astype('Int64')
# <br>2. Заполнить пропуски значением-заглушкой, изменить тип данных, заменить заглушки на nan
#
#     df[col] = df[col].fillna(-1)
#     df[col] = df[col].astype(int)
#     df[col] = df[col].replace('-1', np.nan)
# </div>

# %%
# 3. Изучите уникальные значения в столбце с названиями и устраните неявные дубликаты.
# Проверим уникальные значения в столбце "названия нас. пунктов":
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %%
# Уберем обозначения территориальных образований и оставим только их названия:
data['locality_name'] = data['locality_name'].str.replace('поселок ', '')
data['locality_name'] = data['locality_name'].str.replace('посёлок ', '')
data['locality_name'] = data['locality_name'].str.replace('городского типа ', '')
data['locality_name'] = data['locality_name'].str.replace('деревня ', '')
data['locality_name'] = data['locality_name'].str.replace('садовое товарищество ', '')
data['locality_name'] = data['locality_name'].str.replace('городской ', '')
data['locality_name'] = data['locality_name'].str.replace('село ', '')
data['locality_name'] = data['locality_name'].str.replace('станции ', '')
data['locality_name'] = data['locality_name'].str.replace('при железнодорожной станции ', '')
data['locality_name'] = data['locality_name'].str.replace('коттеджный ', '')
data['locality_name'] = data['locality_name'].str.replace('садоводческое некоммерческое товарищество ', '')
data['locality_name'] = data['locality_name'].str.replace('при железнодорожной ', '')
data['locality_name'] = data['locality_name'].str.replace('Пансионат ', '')
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'Шушары', 'Янино-1', 'Парголово', 'Мурино',
#        'Ломоносов', 'Сертолово', 'Петергоф', 'Пушкин', 'Кудрово',
#        'Коммунар', 'Колпино', 'Красный Бор', 'Гатчина', 'Фёдоровское',
#        'Выборг', 'Кронштадт', 'Кировск', 'Новое Девяткино',
#        'Металлострой', 'Лебяжье', 'Сиверский', 'Молодцово',
#        'Кузьмоловский', 'Новая Ропша', 'Павловск', 'Пикколово',
#        'Всеволожск', 'Волхов', 'Кингисепп', 'Приозерск', 'Сестрорецк',
#        'Куттузи', 'Аннино', 'Ефимовский', 'Плодовое', 'Заклинье',
#        'Торковичи', 'Первомайское', 'Красное Село', 'Понтонный',
#        'Сясьстрой', 'Старая', 'Лесколово', 'Новый Свет', 'Сланцы',
#        'Путилово', 'Ивангород', 'Шлиссельбург', 'Никольское',
#        'Зеленогорск', 'Сосновый Бор', 'Оржицы', 'Кальтино', 'Романовка',
#        'Бугры', 'Рощино', 'Кириши', 'Луга', 'Волосово', 'Отрадное',
#        'Павлово', 'Оредеж', 'Копорье', 'Молодёжное', 'Тихвин', 'Победа',
# ...

# %% [markdown]
# Вывод: В столбце "название населенного пункта" устранены неявные дубликаты, например, одни и те же наименования сочетались с по-разному написанными территориальными образованиями (поселок, посёлок). Для облегчения работы с данным столбцом удалены все обозначения территориальных образований (поселок, село, деревня и т.д.) и оставлены только наименования населенных пунктов. В дальнейшем это облегчит и сделает более наглядными группировки значений и сводные таблицы по населенным пунктам.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Супер! Здесь всё верно)
# </div>

# %%
# 4. Найдите и устраните редкие и выбивающиеся значения.

# Определим выбивающиеся значения в столбце "высота потолков":
data['ceiling_height'].hist()
print(data['ceiling_height'].min())
print(data['ceiling_height'].max())
# Out:
# 1.0
# 100.0

# %% [markdown]
# Вывод: в столбце "высота потолков" значения варьируются от 1 до 100 м.

# %%
# Посмотрим на уникальные значения в столбце "высота потолков":
data['ceiling_height'].sort_values().unique()
data['ceiling_height'].value_counts()
# Out:
# 2.65     9871
# 2.50     3515
# 2.60     1646
# 2.70     1574
# 3.00     1112
#          ...
# 4.25        1
# 3.39        1
# 3.93        1
# 10.30       1
# 4.65        1
# Name: ceiling_height, Length: 183, dtype: int64

# %% [markdown]
# Согласно п.5.8 СНиП 31-01-2003 "Здания жилые многоквартирные",
# высота потолков в жилых помещениях должна составлять не менее 2.7м. С учетом, что
# квартир с высотой потолка 2.5 метра в датафрейме насчитывается примерно 4000 и не желательно терять их из датафрейма или как-то корректировать их параметры, значения в столбце "высота потолка" меньше 2.5 метров  заменим на 2.5 метра.
# Основной разброс значений приходится на 2.65 метров (9871 значений). Можно считать, что это стандартная высота одного этажа для квартир из датафрейма. С учетом, что в датафрейме встречаются значения более 5 метров, которые видимо подразумевают высоту потолка в двухэтажной квартире, значения больше 5.3 метров (2.65 метров * 2 этажа) заменим на 5.3 метров. Предложенный в условии вариант деления площади на 10 не представляется целесообразным, т.к. непонятно, начиная с какого значения стоит делить на 10, и что делать со значением, например, 100м.

# %%
# Восстановим корректные значения столбца "высота потолков": 
data.loc[data['ceiling_height'] < 2.5, 'ceiling_height'] = 2.5
data.loc[data['ceiling_height'] > 5.3, 'ceiling_height'] = 5.3
print(data['ceiling_height'].sort_values().unique())
# Out:
# [2.5  2.51 2.52 2.53 2.54 2.55 2.56 2.57 2.58 2.59 2.6  2.61 2.62 2.63
#  2.64 2.65 2.66 2.67 2.68 2.69 2.7  2.71 2.72 2.73 2.74 2.75 2.76 2.77
#  2.78 2.79 2.8  2.81 2.82 2.83 2.84 2.85 2.86 2.87 2.88 2.89 2.9  2.91
#  2.92 2.93 2.94 2.95 2.96 2.97 2.98 2.99 3.   3.01 3.02 3.03 3.04 3.05
#  3.06 3.07 3.08 3.09 3.1  3.11 3.12 3.13 3.14 3.15 3.16 3.17 3.18 3.2
#  3.21 3.22 3.23 3.24 3.25 3.26 3.27 3.28 3.29 3.3  3.31 3.32 3.33 3.34
#  3.35 3.36 3.37 3.38 3.39 3.4  3.42 3.43 3.44 3.45 3.46 3.47 3.48 3.49
#  3.5  3.51 3.52 3.53 3.54 3.55 3.56 3.57 3.58 3.59 3.6  3.62 3.63 3.65
#  3.66 3.67 3.68 3.69 3.7  3.75 3.76 3.78 3.8  3.82 3.83 3.84 3.85 3.86
#  3.87 3.88 3.9  3.93 3.95 3.98 4.   4.06 4.1  4.14 4.15 4.19 4.2  4.25
#  4.3  4.37 4.4  4.45 4.5  4.65 4.7  4.8  4.9  5.   5.2  5.3 ]

# %% [markdown]
# Вывод: разброс значений в столбце "высота потолков" теперь варьируется от 2.5 до 5.3 метров.

# %%
# Определим выбивающиеся значения в столбце "цена квартиры":
print(data['last_price'].sort_values())
display(data.loc[(data['last_price'] > 30000000)])
(data['last_price']/1000).hist(range = (0, 100000))
# Out:
# 8793         12190.0
# 17456       430000.0
# 14911       430000.0
# 16274       440000.0
# 17676       450000.0
#             ...
# 15651    300000000.0
# 1436     330000000.0
# 14706    401300000.0
# 19540    420000000.0
# 12971    763000000.0
# Name: last_price, Length: 23699, dtype: float64
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3                 0  64900000.0       159.0           2015-07-24      3
# 51                7  45000000.0       161.0           2017-10-17      3
# 121              20  33000000.0       180.0           2017-02-17      3
# 155               8  96000000.0       317.0           2017-07-07      4
# 262              14  37500000.0       158.0           2019-01-24      4
# ...             ...         ...         ...                  ...    ...
# 23005            20  30750000.0       297.5           2018-09-09      6
# 23091            20  33000000.0       186.0           2017-10-11      3
# ...

# %% [markdown]
# В столбце "цена квартиры" есть одно выбивающееся значение в сумме 12 190 руб., при этом площадь этой квартиры составляет 109 кв.м. Также выбивающимися можно считать квартиры с ценой более 30 млн руб., таких насчитывается 316 штук.

# %%
# Удалим выбивающееся значение в столбце "цена" в сумме 12190 руб.: 
data = data.loc[data['last_price'] != 12190.00]
data['last_price'].min()
# Out:
# 430000.0

# %%
# Удалим из датафрейма квартиры с ценой более 30 млн руб.: 
data = data.loc[data['last_price'] <= 30000000]
print(data['last_price'].max())
data.info()
# Out:
# 30000000.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23382 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23382 non-null  int64
#  1   last_price            23382 non-null  float64
#  2   total_area            23382 non-null  float64
#  3   first_day_exposition  23382 non-null  datetime64[ns]
#  4   rooms                 23382 non-null  int64
#  5   ceiling_height        23382 non-null  float64
#  6   floors_total          23382 non-null  int64
#  7   living_area           23382 non-null  float64
#  8   floor                 23382 non-null  float64
#  9   is_apartment          23382 non-null  bool
#  10  studio                23382 non-null  bool
#  11  open_plan             23382 non-null  bool
#  12  kitchen_area          23382 non-null  float64
#  13  balcony               23382 non-null  int64
# ...

# %% [markdown]
# После удаления выбивающихся значений в столбце "цена квартиры" минимальная цена на квартиру в датафрейме составляет 430 000 руб., максимальная - 30 000 000 руб.

# %%
# Определим выбивающиеся значения в столбце "кол-во комнат":
print(data['rooms'].value_counts())
# Out:
# 1     8042
# 2     7918
# 3     5717
# 4     1108
# 5      266
# 0      196
# 6       78
# 7       38
# 8        7
# 9        6
# 10       2
# 14       2
# 16       1
# 11       1
# Name: rooms, dtype: int64

# %% [markdown]
# Вывод: в столбце "кол-во комнат" 196 квартир имеют количество комнат, равное 0. Также в датафрейме присутствует небольшое количество квартир с количеством комнат более 5, эти значения тоже можно считать выбивающимися.

# %%
# Заменим число комнат с 0 на 1 по квартирам, где количество комнат равно 0:
data['rooms'] = data['rooms'].replace(0, 1)
print(data['rooms'].value_counts())
# Out:
# 1     8238
# 2     7918
# 3     5717
# 4     1108
# 5      266
# 6       78
# 7       38
# 8        7
# 9        6
# 10       2
# 14       2
# 16       1
# 11       1
# Name: rooms, dtype: int64

# %%
# Отбросим из датафрейма строки с квартирами, число комнат которых больше 5:
data = data.loc[data['rooms'] <= 5]
print(data['rooms'].value_counts())
# Out:
# 1    8238
# 2    7918
# 3    5717
# 4    1108
# 5     266
# Name: rooms, dtype: int64

# %% [markdown]
# Вывод: количество комнат в квартирах в датафрейме находится в пределах между 1 и 5 комнатами.

# %%
# Определим выбивающиеся значения в столбце "общая площадь":
data['total_area'].hist(bins=30, range=(0,50))
plt.show()
data['total_area'].hist(bins=30)
plt.show()
display(data.loc[data['total_area'] > 200])
display(data.loc[data['total_area'] < 20])
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 521              20  25717300.0      230.10           2015-01-21      3
# 1187             10  25000000.0      201.00           2015-08-07      5
# 2003             23  21000000.0      215.00           2017-11-11      4
# 2176              3  25800000.0      204.00           2017-02-15      5
# 2489              9  12500000.0      255.00           2017-04-21      3
# 3267              1  25092624.0      266.20           2015-12-08      5
# 3303             20  15750000.0      214.00           2018-06-15      4
# 3676             12  28789000.0      441.98           2019-01-23      4
# 4536             25  26000000.0      290.00           2017-11-16      5
# 4549              1  28000000.0      211.00           2016-03-17      5
# 4559              9  29900000.0      240.00           2016-06-01      4
# 4978              8  29000000.0      228.00           2016-12-29      4
# ...

# %% [markdown]
# Вывод: аномальными значениями в столбце "площадь квартиры" можно считать значения более 200 кв.м, таких квартир насчитывается 41, а также значения менее 20 кв.м, таких квартир насчитывается 27.

# %%
# Отбросим из датафрейма строки с квартирами, площадь которых более 200 кв.м:
data = data.loc[data['total_area'] <= 200]
print(data['total_area'].max())
# Out:
# 200.0

# %% [markdown]
# Вывод: после удаления выбивающихся значений в столбце "площадь квартиры" максимальная площадь составляет 200 кв.м

# %%
# Отбросим из датафрейма строки с квартирами, площадь которых менее 20 кв.м:
data = data.loc[data['total_area'] >= 20]
print(data['total_area'].min())
# Out:
# 20.0

# %% [markdown]
# Вывод: после удаления выбивающихся значений в столбце "площадь квартиры" минимальная площадь составляет 20 кв.м.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Давай изучим аномалии в других столбцах. Посмотри какие значения есть в столбцах со стоимостью квартиры, количеством комнат и общей площадью. Кажется, в них есть значения, которые сильно выделяются на общем фоне. Не забудь проверить какое количество данных мы в итоге отбрасываем. Это количество не должно превышать 10% от изначального объёма данных. C этим может помочь следующий код
#
# 	new_data.shape[0] / old_data.shape[0]
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Удалил аномалии в столбцах со стоимостью квартиры и количеством комнат. По столбцу площадь квартир, мне кажется, нет аномалий. В нем много квартир меньше 20 кв.м, но они все имеют одну, максимум две комнаты. Если смотреть большие квартиры, то, например, с площадями более 400 кв.м все цены адекватные.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v2:</b>
# <br>Аномально высокие значения в столбцах с площадью квартир и количеством комнат остались. Аномальное значение не значит, что оно нереальное или не может существовать. Это значит, что такое значение выделяется на общем фоне и встретить его большая редкость. Давай разберём на примере общей площади (график ниже). На графике чётко видно, что после 200м квартир практически нет, а после 300 линии даже не видно. В данном случае аномальными значениями можно считать все квартиры больше 200-300м. Значит эти значения нужно отбросить.
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Дополнительно к ранее удаленным аномалиям удалил следующие аномалии:
#     - в столбце с количеством комнат - квартиры с более чем 5 комнатами;
#     - в столбце цена квартиры - с ценой более 30 млн;
#     - в столбце общая площадь - квартиры более 200 кв.м и менее 20 кв.м.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v3:</b>
# <br>Отлично! Теперь всё верно)
# </div>

# %%
#код ревьюера
data['total_area'].hist(bins=30);

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %%
# Создадим столбец "цена 1 кв. метра":
data['price_1m'] = data['last_price']/data['total_area']
display(data.head(10))
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70            16    51.000000    8.0         False  ...
# ...

# %%
# Создадим столбцы "день недели", "месяц", "год" публикации объявления:
data['day_exposition'] = pd.DatetimeIndex(data['first_day_exposition']).day
data['month_exposition'] = pd.DatetimeIndex(data['first_day_exposition']).month 
data['year_exposition'] = pd.DatetimeIndex(data['first_day_exposition']).year
display(data.head(10))
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70            16    51.000000    8.0         False  ...
# ...

# %%
# Создадим столбец "тип этажа квартиры":
def floor_type(row):
    if row['floor'] == 1:
        return('первый')
    if row['floor'] == row['floors_total']:
        return('последний')
    else:
        return('другой')
data['floor_type'] = data.apply(floor_type, axis = 1)
display(data.head(10))
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70            16    51.000000    8.0         False  ...
# ...

# %%
# Создадим столбец "расстояние до центра города в км":
data['center_km'] = round(data['cityCenters_nearest']/1000)
display(data.head(10))
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70            16    51.000000    8.0         False  ...
# ...

# %% [markdown]
# Вывод: В датафрейм добавлены новые столбцы, в частности, данные о цене за 1 кв.метр по каждому объекту, день, месяц и год публикации объявлений, расстояние до центра в километрах, тип этажа квартиры.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Все необходимые колонки добавлены. Идём дальше)
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %%
# 1. Изучите следующие параметры объектов: 
# Построим гистограммы для следующих параметров объектов:

# %%
# Общая площадь:
plt.title('Общая площадь')
data['total_area'].hist(bins = 50, figsize = (10,5), range = (0,100))
plt.show()

# %% [markdown]
# Вывод: основная масса значений в столбце "площадь квартиры" распределена в диапазоне от 10 до 300м, основной разброс значений - между 30 и 60м, больше всего квартир с площадью примерно 45 кв.м

# %%
# Жилая площадь:
plt.title('Жилая площадь')
data['living_area'].hist(bins = 50, figsize = (10,5), range = (5,30))
plt.show()

# %% [markdown]
# Вывод: основная масса значений в столбце "жилая площадь" распределена в диапазоне от 5 до 200 кв.м, основной разброс значений - между 12 и 50 кв.м, больше всего квартир с жилой площадью примерно 17 кв.м, есть два пика площадей - 17 и 30 кв.м.

# %%
# Площадь кухни:
plt.title('Площадь кухни')
data['kitchen_area'].hist(bins = 50, figsize = (10,5), range = (0,12.5))
plt.show()

# %% [markdown]
# Вывод: основная масса значений в столбце "площадь кухни" распределена в диапазоне от 2 до 40м, основной разброс значений - между 5 и 12,5м, есть несколько пиков площадей: 6, 7, 8, 9, 10м. Наличие таких пиков видимо связано с округлением площадей.

# %%
# Цена объектов в тысячах руб.:
# Для корректности отображения гистограммы разделим значения столбца "цена" на 1000,
# итого значения будут выдаваться в тысячах руб.
data['last_price_tisha'] = data['last_price']/1000
plt.title('Цена объектов в тысячах руб.')
data['last_price_tisha'].hist(bins = 50, figsize = (10,5), range = (0, 10000))
plt.show()

# %% [markdown]
# Вывод: основная масса значений в столбце "цена" распределена в диапазоне от 500 тыс. до 40 млн руб., основной разброс значений - между 2 и 6 млн руб., больше всего квартир с ценой от 3,5 до 4 млн руб.

# %%
# Количество комнат:
plt.title('Количество комнат')
data['rooms'].hist(bins = 50, figsize = (10,5), range = (0,5))
plt.show()

# %% [markdown]
# Вывод: основная масса значений в столбце "кол-во комнат" распределена в диапазоне от 1 до 5, больше всего квартир с 1, 2 и 3 комнатами.

# %%
# Высота потолков:
plt.title('Высота потолков')
data['ceiling_height'].hist(bins = 50, figsize = (10,5), range = (2, 6))
plt.show()

# %% [markdown]
# Вывод: основная масса значений в столбце "высота потолков" распределена в диапазоне от 2.5 до 3.5, больше всего квартир с высотой потолка 2.65м.

# %%
# Этаж:
plt.title('Этаж')
data['floor'].hist(bins = 50, figsize = (10,5), range = (0, 10))
plt.show()

# %% [markdown]
# Вывод: основная масса значений в столбце "этаж" распределена в диапазоне от 1 до 30, основной разброс значений - между 1 и 5 этажами,больше всего квартир на 2-м этаже.

# %%
# Тип этажа:
plt.title('Тип этажа')
data['floor_type'].hist(bins = 50, figsize = (10,5), range = (0, 10))
plt.show()

# %% [markdown]
# Вывод: по данным из столбца "тип этажа" больше всего квартир имеют не первый и не последний этаж, квартир на последнем этаже чуть больше, чем на первом.

# %%
# Всего этажей:
plt.title('Всего этажей')
data['floors_total'].hist(bins = 50, figsize = (10,5), range = (0, 30))
plt.show()

# %% [markdown]
# Вывод: основная масса значений в столбце "всего этажей" распределена в диапазоне от 1 до 30, есть два пика этажности с 5 и 10 этажами.

# %%
# Расстояние до центра:
plt.title('Расстояние до центра')
data['cityCenters_nearest'].hist(bins = 50, figsize = (10,5), range = (0, 40000))
plt.show()

# %% [markdown]
# Вывод: основная масса значений в столбце "расстояние до центра" распределена в диапазоне от 0 до 35 км, основной разброс значений - между 2.5 и 17 км, пик значений приходится на 15 км.

# %%
# Расстояние до аэропорта:
plt.title('Расстояние до аэропорта')
data['airports_nearest'].hist(bins = 50, figsize = (10,5), range = (10000, 30000))
plt.show()

# %% [markdown]
# Вывод: основная масса значений в столбце "расстояние до аэропорта" распределена в диапазоне от 6 до 60 км, основной разброс значений - между 10 и 50 км, пик значений приходится примерно на 18.5 км.

# %%
# Расстояние до парка:
plt.title('Расстояние до парка')
data['parks_nearest'].hist(bins = 50, figsize = (10,5), range = (0, 1000))
plt.show()

# %% [markdown]
# Вывод: основная масса значений в столбце "расстояние до парка" распределена в диапазоне от 0 до 2 км, основной разброс значений - между 200 и 700 м, пик значений приходится примерно на 450м.

# %%
# День публикации объявления:
plt.title('День публикации объявления')
data['day_exposition'].hist(bins = 50, figsize = (10,5), range = (0, 7))
plt.show()

# %% [markdown]
# Вывод: в столбце "день размещения объявлений" распределение по дням примерно равномерное, пик размещения приходится на понедельник.

# %%
# Месяц публикации объявления:
plt.title('Месяц публикации объявления')
data['month_exposition'].hist(bins = 50, figsize = (10,5), range = (0, 12))
plt.show()

# %% [markdown]
# Вывод: из столбца "месяц размещения объявлений" следует, что больше всего объявлений размещается в феврале, марте, апреле и в осенние месяцы, меньше всего - в мае, декабре и январе.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Ты корректно подбираешь основные диапазоны, а также верно читаешь графики!
# </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Для того чтобы подписать график мы можем использовать метод plt.title() и в конце кода применить plt.show(). По ссылкам ниже можно почитать подробнее как добавить название для графика или подписать его оси
#
#     https://pyprog.pro/mpl/mpl_title.html
#     https://pyprog.pro/mpl/mpl_axis_signatures.html
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Подписал графики выше.
# </div>

# %%
# 2. Изучите, как быстро продавались квартиры (столбец days_exposition).
plt.title('Срок размещения объявления')
data['days_exposition'].hist(bins = 50, figsize = (10,5), range = (0,1000))
plt.show()
print(data['days_exposition'].mean())
print(data['days_exposition'].median())
# Out:
# 178.8778197356653
# 94.0

# %% [markdown]
# Вывод: В большинстве случаев квартиры продаются в течение полугода (на графике - 200 дней).
# Быстрой можно считать продажу в течение 3 месяцев, долгой - от 0.5 до 1.5 лет,
# неоправданно долгой - от 1,5 до 2,5 лет.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Согласен! Если интересно, то можно посмотреть на диапазон от 0 до 100 дней. Там есть пики, которым можно найти очень логичное объяснение</div>
# </div>

# %%
# 3. Какие факторы больше всего влияют на общую (полную) стоимость объекта?

# Построим диаграмму рассеяния и определим коэффициент корреляции, показывающие 
# зависимость цены от общей площади квартиры. Здесь и далее по оси Y будем брать значения цены в тыс. руб.:
print(data.plot(x='total_area', y='last_price_tisha', kind='scatter', figsize=(15, 9), xlim=(0, 300), 
ylim=(0, 100000)))
print(data['total_area'].corr(data['last_price_tisha']))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 0.7823415830675213

# %% [markdown]
# Вывод: цена квартиры прямо коррелирует с общей площадью квартиры, коэффициент корреляции составляет примерно 0,65.

# %%
# Построим диаграмму рассеяния и определим коэффициент корреляции, 
# показывающие зависимость цены от жилой площади квартиры:
print(data.plot(x='living_area', y='last_price_tisha', kind='scatter', figsize=(15, 9), xlim=(0, 300), 
ylim=(0, 100000)))
print(data['living_area'].corr(data['last_price_tisha']))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 0.6725242990698237

# %% [markdown]
# Вывод: цена квартиры прямо коррелирует с жилой площадью квартиры, коэффициент корреляции составляет примерно 0,59.

# %%
# Построим диаграмму рассеяния и определим коэффициент корреляции, показывающие
# зависимость цены от площади кухни в квартире:
print(data.plot(x='kitchen_area', y='last_price_tisha', kind='scatter', figsize=(15, 9), xlim=(0, 300), 
ylim=(0, 100000)))
print(data['last_price_tisha'].corr(data['kitchen_area']))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 0.6163043691969331

# %% [markdown]
# Вывод: цена квартиры прямо коррелирует с кухонной площадью, коэффициент корреляции составляет примерно 0,51

# %%
# Построим диаграмму рассеяния и определим коэффициент корреляции, показывающие
# зависимость цены от кол-ва комнат:
print(data.plot(x='rooms', y='last_price_tisha', kind='scatter', figsize=(15, 9), xlim=(0, 15), 
ylim=(0, 100000)))
print(data['last_price_tisha'].corr(data['rooms']))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 0.47983707194229147

# %% [markdown]
# Вывод: самые высокие цены на квартиры характерны для 3-5-комнатных квартир, скорее всего, из-за того, что в датафрейме их больше всего. Коэффициент корреляции составляет 0,36.

# %%
# Построим диаграмму рассеяния, показывающую зависимость цены от этажа:
print(data.plot(x='floor_type', y='last_price_tisha', kind='scatter', figsize=(15, 9), xlim=(0, 3), 
ylim=(0, 100000)))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Тут нужно изучить категорию этажа
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправил расчет и вывод.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# Вывод: в отношении этажности наиболее высокие цены наблюдается для квартир не первого и последнего этажей. Цены на квартиры на первом этаже самые низкие и заметно уступают, в том числе, квартирам на последнем этаже.

# %%
# Построим диаграмму рассеяния, показывающую зависимость цены от дня размещения объявления:
print(data.plot(x='day_exposition', y='last_price_tisha', kind='scatter', figsize=(15, 9), xlim=(0, 31), 
ylim=(0, 100000)))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Вывод: корреляцию между ценой и днем размещения объявления проследить трудно.

# %%
# Построим диаграмму рассеяния, показывающую зависимость цены от месяца размещения объявления:
print(data.plot(x='month_exposition', y='last_price_tisha', kind='scatter', figsize=(15, 9), xlim=(0, 12), 
ylim=(0, 100000)))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Вывод: корреляцию между ценой и месяцем размещения объявления проследить трудно.

# %%
# Построим диаграмму рассеяния, показывающую зависимость цены от года размещения объявления:
print(data.plot(x='year_exposition', y='last_price_tisha', kind='scatter', figsize=(15, 9), xlim=(2014, 2020), 
ylim=(0, 100000)))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Вывод: в отношении года размещения объявлений пик цен наблюдается в 2017 году, после которого началось падение цен на недвижимость.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Тут всё верно) Ещё тут можно использовать для визуализации pairplot из библиотеки seaborn
#
#     https://seaborn.pydata.org/generated/seaborn.pairplot.html
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Давай ещё добавим расчет корреляции для общей площади, жилой площади, площади кухни и количества комнат используя .corr()
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Добавил выше.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %%
# 4. Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом 
# объявлений.
kolich_obyav = data.groupby('locality_name')['locality_name'].count()
sred_cena = data.groupby('locality_name')['price_1m'].mean()
final = kolich_obyav.to_frame().join(sred_cena)
final.columns = ['count', 'price_1m_sred']
display(final.sort_values(by = 'count', ascending = False).head(10))
# Out:
#                  count  price_1m_sred
# locality_name
# Санкт-Петербург  15227  110670.356087
# Мурино             590   86087.512050
# Кудрово            472   95324.930544
# Шушары             439   78655.592167
# Всеволожск         398   68654.473986
# Пушкин             362  103168.298281
# Колпино            337   75333.295801
# Парголово          326   90332.263023
# Гатчина            307   68746.146763
# Выборг             237   58141.909153

# %% [markdown]
# Вывод: больше всего объявлений размещаются в Санкт-Петербурге, Мурино и Кудрово. Из трех указанных населенных пунктов, лидирующих по количеству объявлений, самая высокая средняя стоимость 1 кв.м в Санкт-Петербурге.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Всё верно! Как вариант, тут вместо таблицы можно построить гистограмму, так будет более наглядно)
# </div>

# %%
# Выделим населённые пункты с самой высокой и низкой стоимостью квадратного метра:
print(data.groupby('locality_name')['price_1m'].mean().sort_values().head(10))
print(data.groupby('locality_name')['price_1m'].mean().sort_values(ascending = False).head(10))
# Out:
# locality_name
# Старополье         11206.221198
# Свирь              11481.481481
# Вахнова Кара       11688.311688
# Выскатка           12335.480902
# Совхозный          12629.129129
# Малая Романовка    12724.550898
# Тёсово-4           12931.034483
# Бор                13157.894737
# Сижно              13709.677419
# Ям-Тесово          13711.553373
# Name: price_1m, dtype: float64
# locality_name
# Зеленогорск        115122.799198
# Санкт-Петербург    110670.356087
# Репино             104238.614786
# Пушкин             103168.298281
# Сестрорецк         101912.339326
# Лисий Нос          100660.814239
# Мистолово           98549.976709
# Левашово            96997.690531
# Кудрово             95324.930544
# Парголово           90332.263023
# Name: price_1m, dtype: float64

# %% [markdown]
# Вывод: Из всех населенных пунктов самая высокая стоимость 1 кв. метра в Зеленогорске, самая низкая - в Старополье, Санкт-Петербург - на втором месте.

# %%
# 5. Выделите квартиры в Санкт-Петербурге с помощью столбца locality_name 
# и вычислите среднюю цену каждого километра.
print(data.loc[data['locality_name'] == "Санкт-Петербург"].pivot_table(index='center_km',
values='last_price_tisha', aggfunc='mean'))
# Out:
#            last_price_tisha
# center_km
# 0.0            11318.666667
# 1.0            11618.819870
# 2.0            10755.138996
# 3.0             9464.499539
# 4.0            10063.652423
# 5.0            10590.820469
# 6.0             9402.785034
# 7.0             9272.221383
# 8.0             8769.248009
# 9.0             6772.331085
# 10.0            6345.510011
# 11.0            6075.248955
# 12.0            5780.173300
# 13.0            6049.095831
# 14.0            5589.388146
# 15.0            5784.618951
# 16.0            5351.793776
# 17.0            5199.449684
# 18.0            4868.168508
# 19.0            5037.674936
# 20.0            5951.464837
# 21.0            5493.469368
# 22.0            5415.524282
# 23.0            4689.843373
# 24.0            3854.429615
# 25.0            4052.839923
# 26.0            3973.012509
# 27.0            8300.000000
# 28.0            5026.428571
# 29.0            4236.666667

# %% [markdown]
# Вывод: цена 1 км падает по мере удаления от центра Санкт-Петербурга. Цена на квартиры по мере удаления от центра города падает со средних 31.5 млн до 4.2 млн рублей, т.е. практически в 8 раз.

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>На каком километре заканчивается центр города на твой взгляд, судя по таблице?
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Вероятно на 7-м километре, так как после идет снижение средней цены почти на 50%.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Верно!
#
# </div>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# В проекте рассмотрен архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. В датафрейме насчитывается 22 столбца и 23699 строчек.
# 1. На этапе предобработки проведена следующая работа:
# - В ряде столбцов заменены пропущенные значения, в частности, в столбцах "высота потолков", "кол-во этажей", "жилая площадь" и "площадь кухни" пропущенные значения заполнены средними величинами, в столбце "кол-во балконов" пропуски заменены на ноль, в столбце "апартамент" пропуски заменены на False (т.е. не являются апартаментами), в столбцах с картографическими данными пропуски не заменялись во избежание искажения данных;
# - Во избежание дальнейших ошибок заменены типы данных в некоторых столцах. В частности, в столбцах с количественными показателями, где это возможно, тип данных float заменен на int, а в столбце "дата размещения объявления" тип данных заменен на datetime;
# - В столбце с названиями населенных пунктов устранены неявные дубликаты, чтобы в дальнейшем не возникало ошибок при расчете средней цены объектов недвижимости по населенным пунктам;
# - В столбце "высота потолков" устранены выбивающиеся значения. В частности, в квартирах с высотой потолков менее 2.5 метров высота принята за 2.5 метра, а в квартирах с высотой потолков более 5.3 метров высота принята за 5.3 метров.
# - В столбце "цена квартиры" удалено выбивающееся значение в размере 12190 руб., а также квартиры с ценой более 30 млн руб.;
# - В столбце "кол-во комнат" нулевые значения заменены на единицу, также отброшены квартиры с более чем 5 комнатами;
# - В столбце "площадь квартиры" отброшены квартиры с площадью менее 20 кв.м и более 200 кв.м;
# - Для более детального проведения анализа данных в датафрейм добавлены новые столбцы, в частности, данные о цене за 1 кв.метр по каждому объекту, день, месяц и год публикации объявлений, расстояние до центра в километрах, тип этажа квартиры.
# 2. В рамках исследовательского анализа данных выявлено:
# - В датафрейме больше всего квартир с площадью 45 кв.м c жилой площадью 17 кв.м и площадью кухни от 6 до 10 кв.м.
# - Большинство квартир имеют 1, 2 или 3 комнаты, высоту потолков 2.65 метров, расположены на 2-м этаже, пик этажности по домам приходится на 5 и 10 этажей.
# - В среднем квартиры расположены в 15 км от центра г.Санкт-Петербург, в 18.5 км от аэропорта, среднее расстоение до ближайшего парка составляет 450 метров.
# - Больше всего объявлений о продажах размещается по понедельникам в феврале, марте, апреле и в осенние месяцы, меньше всего - в мае, декабре и январе. В большинстве случаев квартиры продаются в течение полугода, реже - от полугода до полутора лет.
# 3. В части ценообразования выявлено:
# - В среднем квартиры оцениваются в сумму от 3.5 до 4 млн рублей.
# - Цена квартиры прямо коррелирует с общей площадью, жилой площадью и площадью кухни.
# - За период наблюдения с 2014 по 2019 года пик цен пришелся на 2017 год, корреляцию между ценой и днем или месяцем размещения объявления проследить трудно.
# - Самая высокая средняя стоимость одного квадратного метра выявлена в Зеленогорске, на втором месте - г.Санкт-Петербург, самая низкая - в Старополье.
# - В г.Санкт-Петербург стоимость квартир напрямую коррелирует с удаленностью от центра, в частности, средняя цена за один квадратный метр по мере удаления от центра на максимум 29 км падает примерно в 8 раз.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>После всех внесённых правок, обязательно перепроверь общий вывод и промежуточные выводы и поправь их по необходимости
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправил.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Итоговый комментарий ревьюера v1:</b>
# <br>Ты хорошо потрудился, большая часть работы сделана, но остаётся внести следующие правки:
# <br>- написать короткий вывод после первичного просмотра данных
# <br>- не заполнять пропуски в столбце days_exposition
# <br>- отбросить аномальные значения (площадь квартиры, стоимость, количество комнат)
# <br>- изучить влияние категории этажа на цену
# <br>- добавить расчет корреляции
# <br>- поправить выводы там, где это необходимо
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Итоговый комментарий ревьюера v2:</b>
# <br>Остались две правки:
# <br>- отбросить аномальные значения (площадь квартиры, стоимость, количество комнат)
# <br>- поправить выводы там, где это необходимо
# </div>
# <div class="alert alert-info">
# <b>Комментарий студента: выводы везде поправил</b>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Итоговый комментарий ревьюера v3:</b>
# <br>Все правки выполнены. Молодец!
# <br>Проделана огромная работа! У тебя подробные, понятные и логичные выводы, которые ты подкрепляешь фактами. Были использованы разные графики и способы, чтобы как можно более тщательно изучить данные и у тебя это получилось!
# <br>Я рад был поработать над проверкой твоей работы) В качестве дополнительного материала для изучения могу порекомендовать следующий ресурс:
#
# 	https://www.python-graph-gallery.com/
# <br>В нем содержится большая библиотека графиков с готовым кодом, который можно использовать при работе.
# <br>Поздравляю со сдачей проекта и желаю удачи в дальнейшем обучении! 😉
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
